# %% [markdown]
# # string to integer

# %%
a="123"
num = 0
for i in a:
    digit=ord(i)-ord('0')
    num=num*10 + digit
print(num)
print(type(num))
# Out:
# 123
# <class 'int'>

# %%
print(chr(1+ord('0')))
# Out:
# 1

# %% [markdown]
# #  integer to string

# %%
import math
a=123
s=""
length = abs(int(math.log10(123)) + 1)
while a>0:
    rem = a%10
    s=s + chr(rem+ord('0'))
    a=a//10
s=s[::-1]
print(s)
# Out:
# 123
