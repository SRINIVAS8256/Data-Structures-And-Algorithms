# %%
# reverse the string
ascii=[]
string="srinivas"
def r(string):
    for i in range(len(string)-1,-1,-1):
        ascii.append(string[i])
    return ''.join(ascii)
r(string)

# %%
num=1234
def rev(num):
    if num not in range(-2**31, 2**31-1):
        return 0
        # a=2**31
        # a.bit_length() 32 bits
        # a=-2**31  32 bits
       
rev(num)

# %%
a=-2**31
a.bit_length()
# Out:
# 32

# %%
def reverse(x: int) -> int:
        if x not in range(-2**31,2**31-1):
            return 0
        ans=0
        while x != 0:
            rem=x%10
            ans=ans*10+rem
            x=x//10
        if x <0:
            ans=ans*-1
        return ans
reverse(-123)

# %%
import math
num=123
print(int(math.log10(num) + 1))#using log
# Out:
# 3

# %%
# to check palindrome
x=121
temp=x
ans=0
while x != 0:
    rem=x%10
    ans=ans*10+rem
    x=x//10
if x <0:
    ans=ans*-1
if temp == ans :
    print("palindrome")
else:
    print("not palindrome|")
# Out:
# palindrome

# %%
# Linear search
def ls(arr,target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return 0
arr=[1,2,34,54,5456,34,31,8]
target =8
ls(arr,target)
# Out:
# 7

# %% [markdown]
# # Digits

# %%
# counting the numbers in the integer and reversing the integer 

def reversing(num):
    ans =0
    while(num>0):
        rem=num%10
        ans=ans*10 + rem
        num=num//10
    return ans


# if num is negative
def neg_num(num):
    ans = 0
    if num < 0:
        num=num*-1
        negative = True
    while(num>0):
        rem=num%10
        ans=ans*10 + rem
        num=num//10
    if negative == True:
        return ans*-1
    else:
        return ans
    
print(reversing(321))
print(neg_num(-3210))
# Out:
# 123
# -123
