# %%
def f1():
    print(1)
    f1()
def main():
    count=0
    f1()
main()

# %%
count = 0
def f2():
    global count
    print(count)
    count=count+1
    if count == 4:
        return
    f2()

def main():
    f2()
main()
# Out:
# 0
# 1
# 2
# 3
